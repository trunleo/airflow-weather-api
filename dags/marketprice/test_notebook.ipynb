# %%
from trino.dbapi import connect
from trino.auth import BasicAuthentication
import pandas as pd

# %%
conn = connect(
    host="trino.aisac-dev.vnsilicon.cloud",
    port=443,
    catalog="glue_dp",
    auth=BasicAuthentication("de", "KSRmKaBCcuyAGZML"),
    schema="dp_silver"
)

# %%
df = pd.read_sql_query("SELECT * FROM dp_silver.dim_categories WHERE price_date >= 2025-12-29 AND price_date <= 2025-12-29", conn)
# Out:
# /var/folders/fc/mgc_t1mn5kq1njs8pzw1jrn00000gp/T/ipykernel_8112/2616319211.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM dp_silver.dim_categories WHERE price_date >= 2025-12-29 AND price_date <= 2025-12-29", conn)
# ---------------------------------------------------------------------------
# TrinoUserError                            Traceback (most recent call last)
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/Personal/Project/airflow/.venv/lib/python3.13/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# ...

# %%
df
# Out:
#        price_date country_code category_id product_id price_type  \
# 0      2025-11-03           TH      P11000     P11003    ขายปลีก
# 1      2025-11-03           TH      P11000     P11009    ขายปลีก
# 2      2025-11-03           TH      P11000     P11011    ขายปลีก
# 3      2025-11-19           TH      P11000     P11001    ขายปลีก
# 4      2025-11-19           TH      P11000     P11023    ขายปลีก
# ...           ...          ...         ...        ...        ...
# 23225  2025-11-07           TH      W18000     W18094     ขายส่ง
# 23226  2025-11-07           TH      W18000     W18099     ขายส่ง
# 23227  2025-11-07           TH      W18000     W18103     ขายส่ง
# 23228  2025-11-07           TH      W18000     W18105     ขายส่ง
# 23229  2025-11-07           TH      W18000     W18107     ขายส่ง
#
#       price_type_en unit_id currency_code  min_price  max_price  avg_price  \
# 0            retail       1           THB      130.0      150.0     140.00
# ...

# %%
df
# Out:
#        price_date country_code category_id product_id price_type  \
# 0      2025-11-07           TH      P11000     P11003    ขายปลีก
# 1      2025-11-07           TH      P11000     P11005    ขายปลีก
# 2      2025-11-07           TH      P11000     P11006    ขายปลีก
# 3      2025-11-07           TH      P11000     P11017    ขายปลีก
# 4      2025-11-07           TH      P11000     P11019    ขายปลีก
# ...           ...          ...         ...        ...        ...
# 18370  2025-11-04           TH      W18000     W18042     ขายส่ง
# 18371  2025-11-04           TH      W18000     W18045     ขายส่ง
# 18372  2025-11-04           TH      W18000     W18078     ขายส่ง
# 18373  2025-11-04           TH      W18000     W18097     ขายส่ง
# 18374  2025-11-04           TH      W18000     W18105     ขายส่ง
#
#       price_type_en  unit_id currency_code  min_price  max_price  avg_price  \
# 0            retail      1.0           THB      130.0      150.0      140.0
# ...
