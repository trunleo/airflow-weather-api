# %%
from trino.dbapi import connect
from trino.auth import BasicAuthentication
import pandas as pd

# %%
conn = connect(
    host="trino.aisac-dev.vnsilicon.cloud",
    port=443,
    catalog="glue_dp",
    auth=BasicAuthentication("de", "KSRmKaBCcuyAGZML")
)

# %%
df = pd.read_sql_query("SELECT * FROM dp_gold.daily_product_prices", conn)
# Out:
# /var/folders/fc/mgc_t1mn5kq1njs8pzw1jrn00000gp/T/ipykernel_74440/581219153.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM dp_gold.daily_product_prices", conn)

# %%
df.columns.tolist()
# Out:
# ['id', 'category_name', 'category_name_en', 'country_code', 'created_at']

# %%
df
# Out:
#      date_time country_code category_id          category_name  \
# 0   2026-01-05           TH      P11000             เนื้อสัตว์
# 1   2026-01-05           TH      P11000             เนื้อสัตว์
# 2   2026-01-05           TH      P11000             เนื้อสัตว์
# 3   2026-01-05           TH      P11000             เนื้อสัตว์
# 4   2026-01-05           TH      P11000             เนื้อสัตว์
# ..         ...          ...         ...                    ...
# 926 2025-12-30           TH      W18000  พืชน้ำมันและน้ำมันพืช
# 927 2025-12-30           TH      W18000  พืชน้ำมันและน้ำมันพืช
# 928 2025-12-30           TH      W18000  พืชน้ำมันและน้ำมันพืช
# 929 2025-12-30           TH      W18000  พืชน้ำมันและน้ำมันพืช
# 930 2025-12-30           TH      W18000  พืชน้ำมันและน้ำมันพืช
#
#     category_name_en price_type price_type_en product_id  \
# 0               Meat    ขายปลีก        retail     P11003
# 1               Meat    ขายปลีก        retail     P11006
# ...
